# %%
# This is a single line comment

"""
This is a
multi-line comment
"""

print("Learning Python Comments")
# Out:
# Learning Python Comments

# %%
# Creating variables
name = "Shariqa"
age = 21
course = "Data Science Internship"

print(name)
print(age)
print(course)
# Out:
# Shariqa
# 21
# Data Science Internship

# %%
# Different data types in Python

integer_value = 10
float_value = 3.14
string_value = "Python"
boolean_value = True

print(type(integer_value))
print(type(float_value))
print(type(string_value))
print(type(boolean_value))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
name = "Shariqa"
age = 21
print("My name is", name)
print("I am", age, "years old")
# Out:
# My name is Shariqa
# I am 21 years old

# %%
# program to check data types of different values

a = 25
b = 6.7
c = "Python Internship"
d = False

print("Type of a:", type(a))
print("Type of b:", type(b))
print("Type of c:", type(c))
print("Type of d:", type(d))
# Out:
# Type of a: <class 'int'>
# Type of b: <class 'float'>
# Type of c: <class 'str'>
# Type of d: <class 'bool'>

# %%
# program to calculate length of a word

word = input("Enter a word: ")

print("You entered:", word)
print("Number of characters:", len(word))
# Out:
# Enter a word:  fgyhuj
# You entered: fgyhuj
# Number of characters: 6

# %%
# This program stores product information

product_name = "Laptop"   # product name
price = 50000             # product price
stock = True              # availability

print("Product:", product_name)
print("Price:", price)
print("Available:", stock)
# Out:
# Product: Laptop
# Price: 50000
# Available: True

# %%
# joining two strings

first_name = "Shariqa"
last_name = "Fatima"

full_name = first_name + " " + last_name

print("Full Name:", full_name)
# Out:
# Full Name: Shariqa Fatima
